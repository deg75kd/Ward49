# %%
# Import pandas library using an alias
import pandas as pd
# library to handle data in a vectorized manner
import numpy as np

# library to handle JSON files
# import json
# library to handle requests
# import requests
# tranform JSON file into a pandas dataframe
# from pandas.io.json import json_normalize

# convert an address into latitude and longitude values
from geopy.geocoders import Nominatim

# Matplotlib and associated plotting modules
#import matplotlib.cm as cm
#import matplotlib.colors as colors

# map rendering library
import folium

# %%
#library_df = pd.read_excel('ChicagoLibraries.xlsx')
#library_df.head()
ward49_df = pd.read_excel('./data/Ward49.xlsx')
ward49_df.head()
# Out:
#                  name              address     city state      zip  \
# 0         Rogers Park    6907 N. Clark St.  Chicago    IL  60626.0
# 1         Sullivan Hs  6631 N Bosworth Ave      NaN   NaN      NaN
# 2                Gale   1631 W Jonquil Ter      NaN   NaN      NaN
# 3  Acero - De La Cruz    7416 N Ridge Blvd      NaN   NaN      NaN
# 4               Field   7019 N Ashland Ave      NaN   NaN      NaN
#
#             phone                                 hours_of_operation  \
# 0  (312) 744-0156  Sun., Closed; Mon. & Wed., Noon-8; Tue. & Thu....
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
#
#     latitude  longitude                                      url loc_type_pri  \
# 0  42.006708 -87.673408  https://www.chipublib.org/locations/61/      Library
# 1  42.002688 -87.669192                                      NaN       School
# 2  42.021091 -87.671939                                      NaN       School
# 3  42.016476 -87.684406                                      NaN       School
# 4  42.009664 -87.669985                                      NaN       School
#
#         loc_type_sec
# 0            Library
# 1        High School
# 2  Elementary School
# 3  Elementary School
# 4  Elementary School

# %%
ward49_df.dtypes
# Out:
# name                   object
# address                object
# city                   object
# state                  object
# zip                   float64
# phone                  object
# hours_of_operation     object
# latitude              float64
# longitude             float64
# url                    object
# loc_type_pri           object
# loc_type_sec           object
# dtype: object

# %%
#library_df.columns
ward49_df.columns
# Out:
# Index(['name', 'address', 'city', 'state', 'zip', 'phone',
#        'hours_of_operation', 'latitude', 'longitude', 'url', 'loc_type_pri',
#        'loc_type_sec'],
#       dtype='object')

# %%
# get list of location types
location_type_list = ward49_df['loc_type_sec'].drop_duplicates().sort_values().to_list()
location_type_list
# Out:
# ['Artificial Turf Field',
#  'Baseball Jr/Softball',
#  'Baseball Sr',
#  'Basketball Court',
#  'Beach',
#  'Boat Launch Non-Motorized',
#  'Boxing Center',
#  'Community Garden',
#  'Dog Friendly Area',
#  'Elementary School',
#  'Fire Station',
#  'Fitness Center',
#  'Football/Soccer Combo Fld',
#  'Gymnasium',
#  'Handball/Racquet (In)',
#  'High School',
#  'Library',
#  'Nature/Bird Sanctuary',
#  'Playground',
#  'Shuffleboard',
#  'Spray Feature',
#  'Tennis Court',
#  'Volleyball']

# %%
# Get coordinates for Chicago
#address = 'Chicago, IL'
address = 'Rogers Park, Chicago, IL'
geolocator = Nominatim(user_agent='chi_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print("The geographical coordinates of Rogers Park, Chicago, IL are {}, {}".format(latitude, longitude))
# Out:
# The geographical coordinates of Rogers Park, Chicago, IL are 42.0090367, -87.6768492

# %% [markdown]
# ## Create fixed map

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=14)

# %%
# Add markers to the map
for lat, lon, name in zip(ward49_df['latitude'],
                          ward49_df['longitude'],
                          ward49_df['name']):
    label = folium.Popup(str(name), parse_html=True)
    folium.CircleMarker(
       [lat, lon],
       radius=5,
       popup=label,
       fill=True,
       fill_opacity=0.7).add_to(chicago_map)

# %%
# Display the map
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_231969c7047e4e77b8f2b4ff0c249695%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_231969c7047e4e77b8f2b4ff0c249695%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_231969c7047e4e77b8f2b4ff0c249695%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_231969c7047e4e77b8f2b4ff0c249695%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Test interactive map

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=14)

# %%
#ward49_df[ward49_df['location_type'] == 'Library']
ward49_df[ward49_df['loc_type_pri'] == 'Library'][['latitude','longitude']]
# Out:
#     latitude  longitude
# 0  42.006708 -87.673408

# %%
points1 = [(42.006708, -87.673408)]

library_group = folium.FeatureGroup(name='Library').add_to(chicago_map)

for tuple_ in points1:
    label = folium.Popup('Rogers Park Library', parse_html=True)
    library_group.add_child(folium.CircleMarker(
        (42.006708, -87.673408),
        radius=5,
        popup=label,
        fill=True,
        fill_opacity=0.7)
    )

# %%
ward49_df[ward49_df['loc_type_sec'] == 'High School'][['latitude','longitude']]
# Out:
#     latitude  longitude
# 1  42.002688 -87.669192
# 6  42.013031 -87.674818

# %%
points2 = [(42.002688, -87.669192),
           (42.013031, -87.674818)]

hs_group = folium.FeatureGroup(name='High School').add_to(chicago_map)

for tuple_ in points2:
    label = folium.Popup('High School', parse_html=True)
    hs_group.add_child(folium.CircleMarker(
        tuple_,
        radius=5,
        popup=label,
        fill=True,
        fill_opacity=0.7)
    )

# %%
folium.LayerControl().add_to(chicago_map)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_67ad8e620a6848ed917c434159f03304%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_67ad8e620a6848ed917c434159f03304%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_67ad8e620a6848ed917c434159f03304%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_67ad8e620a6848ed917c434159f03304%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Create Interactive Map

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=14)

# %%
fgroup = []

# %%
for i in range(len(location_type_list)):
    #print(i, location_type_list[i])
    fgroup.append(folium.FeatureGroup(name=location_type_list[i]).add_to(chicago_map))
    for row in ward49_df[ward49_df['loc_type_sec'] == location_type_list[i]].itertuples():
        #print(row.name, row.latitude, row.longitude)
        label = folium.Popup(row.name, parse_html=True)
        fgroup[i].add_child(folium.CircleMarker(
            [row.latitude, row.longitude],
            radius=5,
            popup=label,
            fill=True,
            fill_opacity=0.7).add_to(chicago_map)
        )
    
fgroup
# Out:
# [<folium.map.FeatureGroup at 0x2a6a46c58e0>,
#  <folium.map.FeatureGroup at 0x2a6a46c5940>,
#  <folium.map.FeatureGroup at 0x2a6a46c4ee0>,
#  <folium.map.FeatureGroup at 0x2a6a46cc070>,
#  <folium.map.FeatureGroup at 0x2a6a46c4220>,
#  <folium.map.FeatureGroup at 0x2a6a46ccee0>,
#  <folium.map.FeatureGroup at 0x2a6a46d8ee0>,
#  <folium.map.FeatureGroup at 0x2a6a46d8f40>,
#  <folium.map.FeatureGroup at 0x2a6a46d8ac0>,
#  <folium.map.FeatureGroup at 0x2a6a46aea90>,
#  <folium.map.FeatureGroup at 0x2a6a46e59d0>,
#  <folium.map.FeatureGroup at 0x2a6a46e5a00>,
#  <folium.map.FeatureGroup at 0x2a6a46f7e80>,
#  <folium.map.FeatureGroup at 0x2a6a46fd640>,
#  <folium.map.FeatureGroup at 0x2a6a46cc0d0>,
#  <folium.map.FeatureGroup at 0x2a6a46cc700>,
#  <folium.map.FeatureGroup at 0x2a6a46f7760>,
#  <folium.map.FeatureGroup at 0x2a6a46fd880>,
#  <folium.map.FeatureGroup at 0x2a6a46fdc40>,
#  <folium.map.FeatureGroup at 0x2a6a4710ac0>,
#  <folium.map.FeatureGroup at 0x2a6a46e5040>,
#  <folium.map.FeatureGroup at 0x2a6a47109d0>,
#  <folium.map.FeatureGroup at 0x2a6a46fda60>]

# %%
folium.LayerControl().add_to(chicago_map)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_92c3cda9cea04f4180bb425749396155%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_92c3cda9cea04f4180bb425749396155%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_92c3cda9cea04f4180bb425749396155%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_92c3cda9cea04f4180bb425749396155%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Try different marker types

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=14)

# %%
# Add markers to the map
for lat, lon, name in zip(ward49_df['latitude'],
                          ward49_df['longitude'],
                          ward49_df['name']):
    label = folium.Popup(str(name), parse_html=True)
    icon = folium.Icon(color='red', icon='bell', prefix='fa')
    folium.Marker(
       location=[lat, lon],
       icon=icon,
       popup=label).add_to(chicago_map)
    
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_df1157bf8e0b41cf8c15ea0f2d5c680f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_df1157bf8e0b41cf8c15ea0f2d5c680f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_df1157bf8e0b41cf8c15ea0f2d5c680f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_df1157bf8e0b41cf8c15ea0f2d5c680f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Customize interactive map

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=13)

fgroup = []
for i in range(len(location_type_list)):
    #print(i, location_type_list[i])
    fgroup.append(folium.FeatureGroup(name=location_type_list[i]).add_to(chicago_map))
    
    for row in ward49_df[ward49_df['loc_type_sec'] == location_type_list[i]].itertuples():
        #print(row.name, row.latitude, row.longitude)
        label = folium.Popup(row.name, parse_html=True)
        if row.loc_type_sec == 'Elementary School':
            icon = folium.Icon(color='red', icon='bell', prefix='fa')
        elif row.loc_type_sec == 'High School':
            icon = folium.Icon(color='blue', icon='graduation-cap', prefix='fa')
        elif row.loc_type_sec == 'Library':
            icon = folium.Icon(color='green', icon='book', prefix='fa')
        else:
            icon = folium.Icon(color='gray', icon='question-circle', prefix='fa')

        fgroup[i].add_child(folium.Marker(
            location=[row.latitude, row.longitude],
            icon=icon,
            popup=label).add_to(chicago_map)
        )
        
folium.LayerControl().add_to(chicago_map)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_002d2e4680fd4148bfc32f1a723a807f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_002d2e4680fd4148bfc32f1a723a807f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_002d2e4680fd4148bfc32f1a723a807f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_002d2e4680fd4148bfc32f1a723a807f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Not enough icons available to use them. Going back to plain circles.

# %% [markdown]
# ## Interactive Map (take 2)

# %%
#for row in ward49_df[ward49_df['loc_type_sec'] == 'Elementary School'].itertuples():
for row in ward49_df[ward49_df['loc_type_sec'] == 'Beach'].itertuples():
    print(row.address, type(row.address))
    #print(np.isnan(row.address))
    if row.address == 'nan':
        print('This is nan')
# Out:
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=13)

fgroup = []
for i in range(len(location_type_list)):
    fgroup.append(folium.FeatureGroup(name=location_type_list[i],
                                      overlay=True,
                                      show=False).add_to(chicago_map))
    for row in ward49_df[ward49_df['loc_type_sec'] == location_type_list[i]].itertuples():
        if row.loc_type_pri == "Park":
            cir_color = "green"
        elif row.loc_type_pri == "Police":
            cir_color = "blue"
        elif row.loc_type_pri == "Fire Station":
            cir_color = "red"
        elif row.loc_type_pri == "School":
            cir_color = "orange"
        elif row.loc_type_pri == "Library":
            cir_color = "yellow"
        else:
            cir_color = "grey"
            
        tooltip_label = row.name + " " + row.loc_type_sec
        #popup_label = row.name + " " + row.loc_type_sec + " " + row.url
        popup_label = "{} {} {}".format(row.name, row.loc_type_sec, row.address)
        #if np.isnan(row.address):
        #    popup_label = "{} {}".format(row.name, row.loc_type_sec)
        #else:
        #    popup_label = "{} {} {}".format(row.name, row.loc_type_sec, row.address)
            
        label = folium.Popup(html=popup_label, parse_html=True)
        fgroup[i].add_child(folium.CircleMarker(
            [row.latitude, row.longitude],
            radius=5,
            popup=label,
            tooltip=tooltip_label,
            color=cir_color,
            fill=True,
            fill_opacity=0.7).add_to(chicago_map)
        )
        
folium.LayerControl().add_to(chicago_map)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2b32854dd35e4bada2a9e40b925aea5d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2b32854dd35e4bada2a9e40b925aea5d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2b32854dd35e4bada2a9e40b925aea5d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2b32854dd35e4bada2a9e40b925aea5d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Interactive map 3

# %%
def show_loc_type_details(loc_type):
    #print(loc_type)
    display(ward49_df[ward49_df['loc_type_sec'] == loc_type].sort_values('name'))

# %%
show_loc_type_details('High School')
# Out:
#                         name              address city state  zip phone  \
# 6  Chicago Math & Science Hs      7212 N Clark St  NaN   NaN  NaN   NaN
# 1                Sullivan Hs  6631 N Bosworth Ave  NaN   NaN  NaN   NaN
#
#   hours_of_operation   latitude  longitude  url loc_type_pri loc_type_sec
# 6                NaN  42.013031 -87.674818  NaN       School  High School
# 1                NaN  42.002688 -87.669192  NaN       School  High School

# %%
ward49_df[ward49_df['loc_type_sec'] == 'High School'].sort_values('name')
# Out:
#                         name              address city state  zip phone  \
# 6  Chicago Math & Science Hs      7212 N Clark St  NaN   NaN  NaN   NaN
# 1                Sullivan Hs  6631 N Bosworth Ave  NaN   NaN  NaN   NaN
#
#   hours_of_operation   latitude  longitude  url loc_type_pri loc_type_sec
# 6                NaN  42.013031 -87.674818  NaN       School  High School
# 1                NaN  42.002688 -87.669192  NaN       School  High School

# %%
for i in range(len(location_type_list)):
    show_loc_type_details(location_type_list[i])
# Out:
#              name address city state  zip phone hours_of_operation   latitude  \
# 37  Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN  42.015287
#
#     longitude  url loc_type_pri           loc_type_sec
# 37 -87.678675  NaN         Park  Artificial Turf Field
#                  name address city state  zip phone hours_of_operation  \
# 22             Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 48      Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN
# 55    Touhy (Patrick)     NaN  NaN   NaN  NaN   NaN                NaN
# 60  White (Willye B.)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri          loc_type_sec
# 22  42.012211 -87.662485  NaN         Park  Baseball Jr/Softball
# 48  42.015852 -87.676485  NaN         Park  Baseball Jr/Softball
# 55  42.014504 -87.673864  NaN         Park  Baseball Jr/Softball
# 60  42.019666 -87.670323  NaN         Park  Baseball Jr/Softball
#              name address city state  zip phone hours_of_operation   latitude  \
# 24         Loyola     NaN  NaN   NaN  NaN   NaN                NaN  42.011227
# 51  Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN  42.015734
#
#     longitude  url loc_type_pri loc_type_sec
# 24 -87.662087  NaN         Park  Baseball Sr
# 51 -87.677881  NaN         Park  Baseball Sr
#                    name address city state  zip phone hours_of_operation  \
# 18               Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 42  Paschen (Christian)     NaN  NaN   NaN  NaN   NaN                NaN
# 44        Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN
# 59    White (Willye B.)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri      loc_type_sec
# 18  42.012389 -87.661702  NaN         Park  Basketball Court
# 42  42.009168 -87.679927  NaN         Park  Basketball Court
# 44  42.015428 -87.677579  NaN         Park  Basketball Court
# 59  42.019912 -87.671544  NaN         Park  Basketball Court
#                         name address city state  zip phone hours_of_operation  \
# 27                 Columbia      NaN  NaN   NaN  NaN   NaN                NaN
# 29            Fargo (James)      NaN  NaN   NaN  NaN   NaN                NaN
# 12  Griffin (Marion Mahony)      NaN  NaN   NaN  NaN   NaN                NaN
# 10             Howard (Ure)      NaN  NaN   NaN  NaN   NaN                NaN
# 39            Juneway Terr.      NaN  NaN   NaN  NaN   NaN                NaN
# 15              Leone (Sam)      NaN  NaN   NaN  NaN   NaN                NaN
# 19                    Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 41              North Shore      NaN  NaN   NaN  NaN   NaN                NaN
# 40            Prinz (Tobey)      NaN  NaN   NaN  NaN   NaN                NaN
# 52         Rogers (Phillip)      NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri loc_type_sec
# 27  42.004488 -87.657240  NaN         Park        Beach
# 29  42.017081 -87.663039  NaN         Park        Beach
# 12  42.015881 -87.662629  NaN         Park        Beach
# 10  42.018864 -87.663915  NaN         Park        Beach
# 39  42.022445 -87.665221  NaN         Park        Beach
# 15  42.013134 -87.661568  NaN         Park        Beach
# 19  42.009768 -87.659097  NaN         Park        Beach
# 41  42.004035 -87.657344  NaN         Park        Beach
# 40  42.005892 -87.657486  NaN         Park        Beach
# 52  42.021485 -87.664715  NaN         Park        Beach
#             name address city state  zip phone hours_of_operation   latitude  \
# 26  Leone (Sam)      NaN  NaN   NaN  NaN   NaN                NaN  42.013008
#
#     longitude  url loc_type_pri               loc_type_sec
# 26 -87.662216  NaN         Park  Boat Launch Non-Motorized
#       name address city state  zip phone hours_of_operation   latitude  \
# 32  Loyola     NaN  NaN   NaN  NaN   NaN                NaN  42.010931
#
#     longitude  url loc_type_pri   loc_type_sec
# 32 -87.661391  NaN         Park  Boxing Center
#                 name address city state  zip phone hours_of_operation  \
# 64  Dubkin (Leonard)     NaN  NaN   NaN  NaN   NaN                NaN
# 65  Goldberg (Louis)     NaN  NaN   NaN  NaN   NaN                NaN
# 66            Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 63          Triangle     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri      loc_type_sec
# 64  42.017447 -87.670655  NaN         Park  Community Garden
# 65  42.010505 -87.665638  NaN         Park  Community Garden
# 66  42.007634 -87.659606  NaN         Park  Community Garden
# 63  42.022543 -87.674460  NaN         Park  Community Garden
#              name address city state  zip phone hours_of_operation   latitude  \
# 36  Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN  42.017039
#
#     longitude  url loc_type_pri       loc_type_sec
# 36 -87.676734  NaN         Park  Dog Friendly Area
#                  name               address city state  zip phone  \
# 3  Acero - De La Cruz     7416 N Ridge Blvd  NaN   NaN  NaN   NaN
# 4               Field    7019 N Ashland Ave  NaN   NaN  NaN   NaN
# 2                Gale    1631 W Jonquil Ter  NaN   NaN  NaN   NaN
# 5              Jordan    7414 N Wolcott Ave  NaN   NaN  NaN   NaN
# 7              Kilmer  6700 N Greenview Ave  NaN   NaN  NaN   NaN
# 8           New Field      1707 W Morse Ave  NaN   NaN  NaN   NaN
#
#   hours_of_operation   latitude  longitude  url loc_type_pri  \
# 3                NaN  42.016476 -87.684406  NaN       School
# 4                NaN  42.009664 -87.669985  NaN       School
# 2                NaN  42.021091 -87.671939  NaN       School
# 5                NaN  42.017088 -87.677763  NaN       School
# 7                NaN  42.003640 -87.668222  NaN       School
# 8                NaN  42.007703 -87.673168  NaN       School
#
#         loc_type_sec
# 3  Elementary School
# 4  Elementary School
# 2  Elementary School
# 5  Elementary School
# 7  Elementary School
# 8  Elementary School
#     name          address     city state      zip phone hours_of_operation  \
# 67  E102  7340 N Clark St  Chicago    IL  60626.0   NaN                NaN
#
#     latitude  longitude  url  loc_type_pri  loc_type_sec
# 67  42.01464 -87.675024  NaN  Fire Station  Fire Station
#                  name address city state  zip phone hours_of_operation  \
# 46      Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN
# 62  White (Willye B.)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri    loc_type_sec
# 46  42.015126 -87.678106  NaN         Park  Fitness Center
# 62  42.019682 -87.671366  NaN         Park  Fitness Center
#                name address city state  zip phone hours_of_operation  \
# 20           Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 45    Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN
# 54  Touhy (Patrick)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri               loc_type_sec
# 20  42.007263 -87.658408  NaN         Park  Football/Soccer Combo Fld
# 45  42.016110 -87.677170  NaN         Park  Football/Soccer Combo Fld
# 54  42.014834 -87.673601  NaN         Park  Football/Soccer Combo Fld
#                  name address city state  zip phone hours_of_operation  \
# 16       Leone (Sam)      NaN  NaN   NaN  NaN   NaN                NaN
# 21             Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 47      Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN
# 34  White (Willye B.)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri loc_type_sec
# 16  42.013164 -87.662535  NaN         Park    Gymnasium
# 21  42.010891 -87.661600  NaN         Park    Gymnasium
# 47  42.015249 -87.678207  NaN         Park    Gymnasium
# 34  42.019732 -87.671512  NaN         Park    Gymnasium
#              name address city state  zip phone hours_of_operation   latitude  \
# 35  Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN  42.015183
#
#     longitude  url loc_type_pri           loc_type_sec
# 35  -87.67814  NaN         Park  Handball/Racquet (In)
#                         name              address city state  zip phone  \
# 6  Chicago Math & Science Hs      7212 N Clark St  NaN   NaN  NaN   NaN
# 1                Sullivan Hs  6631 N Bosworth Ave  NaN   NaN  NaN   NaN
#
#   hours_of_operation   latitude  longitude  url loc_type_pri loc_type_sec
# 6                NaN  42.013031 -87.674818  NaN       School  High School
# 1                NaN  42.002688 -87.669192  NaN       School  High School
#           name            address     city state      zip           phone  \
# 0  Rogers Park  6907 N. Clark St.  Chicago    IL  60626.0  (312) 744-0156
#
#                                   hours_of_operation   latitude  longitude  \
# 0  Sun., Closed; Mon. & Wed., Noon-8; Tue. & Thu....  42.006708 -87.673408
#
#                                        url loc_type_pri loc_type_sec
# 0  https://www.chipublib.org/locations/61/      Library      Library
#       name address city state  zip phone hours_of_operation   latitude  \
# 38  Loyola     NaN  NaN   NaN  NaN   NaN                NaN  42.006654
#
#     longitude  url loc_type_pri           loc_type_sec
# 38 -87.656406  NaN         Park  Nature/Bird Sanctuary
#                         name address city state  zip phone hours_of_operation  \
# 30          Goldberg (Louis)     NaN  NaN   NaN  NaN   NaN                NaN
# 9          Hartigan (David)      NaN  NaN   NaN  NaN   NaN                NaN
# 11             Howard (Ure)      NaN  NaN   NaN  NaN   NaN                NaN
# 13   Langdon (Mary Margaret)     NaN  NaN   NaN  NaN   NaN                NaN
# 14            Lazarus (Emma)     NaN  NaN   NaN  NaN   NaN                NaN
# 17              Leone (Sam)      NaN  NaN   NaN  NaN   NaN                NaN
# 23                    Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 28          Matanky (Eugene)     NaN  NaN   NaN  NaN   NaN                NaN
# 43       Paschen (Christian)     NaN  NaN   NaN  NaN   NaN                NaN
# 49             Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN
# 56           Touhy (Patrick)     NaN  NaN   NaN  NaN   NaN                NaN
# 58  Washington (Harold) Mem.     NaN  NaN   NaN  NaN   NaN                NaN
# 61         White (Willye B.)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri loc_type_sec
# 30  42.010662 -87.665660  NaN         Park   Playground
# 9   42.002272 -87.657694  NaN         Park   Playground
# 11  42.019075 -87.664249  NaN         Park   Playground
# 13  42.001884 -87.674874  NaN         Park   Playground
# 14  42.004178 -87.663190  NaN         Park   Playground
# 17  42.013190 -87.663162  NaN         Park   Playground
# 23  42.010896 -87.660610  NaN         Park   Playground
# 28  42.007428 -87.680525  NaN         Park   Playground
# 43  42.009169 -87.679507  NaN         Park   Playground
# 49  42.014785 -87.678592  NaN         Park   Playground
# 56  42.015640 -87.672752  NaN         Park   Playground
# 58  42.021491 -87.673387  NaN         Park   Playground
# 61  42.020211 -87.670914  NaN         Park   Playground
#       name address city state  zip phone hours_of_operation   latitude  \
# 31  Loyola     NaN  NaN   NaN  NaN   NaN                NaN  42.010592
#
#     longitude  url loc_type_pri  loc_type_sec
# 31  -87.66033  NaN         Park  Shuffleboard
#              name address city state  zip phone hours_of_operation   latitude  \
# 50  Pottawattomie     NaN  NaN   NaN  NaN   NaN                NaN  42.014947
#
#     longitude  url loc_type_pri   loc_type_sec
# 50  -87.67858  NaN         Park  Spray Feature
#                  name address city state  zip phone hours_of_operation  \
# 25             Loyola     NaN  NaN   NaN  NaN   NaN                NaN
# 53  Rogers (Phillip)      NaN  NaN   NaN  NaN   NaN                NaN
# 57    Touhy (Patrick)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri  loc_type_sec
# 25  42.006443 -87.658163  NaN         Park  Tennis Court
# 53  42.020905 -87.664566  NaN         Park  Tennis Court
# 57  42.014080 -87.674659  NaN         Park  Tennis Court
#                    name address city state  zip phone hours_of_operation  \
# 33  Paschen (Christian)     NaN  NaN   NaN  NaN   NaN                NaN
#
#      latitude  longitude  url loc_type_pri loc_type_sec
# 33  42.009118 -87.679722  NaN         Park   Volleyball

# %%
# Create a map
chicago_map = folium.Map(location=[latitude, longitude],
                         zoom_start=13)

fgroup = []
for i in range(len(location_type_list)):
    fgroup.append(folium.FeatureGroup(name=location_type_list[i],
                                      overlay=True,
                                      #layeradd=show_loc_type_details(location_type_list[i]), -> shows all groups at the start
                                      #on=('click', show_loc_type_details(location_type_list[i])), -> same result
                                      #on=('select', show_loc_type_details(location_type_list[i])), -> same result
                                      show=False).add_to(chicago_map))
    for row in ward49_df[ward49_df['loc_type_sec'] == location_type_list[i]].itertuples():
        if row.loc_type_pri == "Park":
            cir_color = "green"
        elif row.loc_type_pri == "Police":
            cir_color = "blue"
        elif row.loc_type_pri == "Fire Station":
            cir_color = "red"
        elif row.loc_type_pri == "School":
            cir_color = "orange"
        elif row.loc_type_pri == "Library":
            cir_color = "yellow"
        else:
            cir_color = "grey"
            
        tooltip_label = row.name + " " + row.loc_type_sec
        #popup_label = row.name + " " + row.loc_type_sec + " " + row.url
        popup_label = "{} {} {} {}".format(row.name, row.loc_type_sec, row.address, row.url)
            
        label = folium.Popup(html=popup_label, parse_html=True)
        fgroup[i].add_child(folium.CircleMarker(
            [row.latitude, row.longitude],
            radius=5,
            popup=label,
            tooltip=tooltip_label,
            color=cir_color,
            fill=True,
            fill_opacity=0.7).add_to(chicago_map)
        )
        
folium.LayerControl().add_to(chicago_map)
#folium.map.CustomPane('testpane', pointer_events=True).add_to(chicago_map) -> does nothing
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3c28c577d1e242e3b00668a68fd70c20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3c28c577d1e242e3b00668a68fd70c20%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3c28c577d1e242e3b00668a68fd70c20%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3c28c577d1e242e3b00668a68fd70c20%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.0090367%2C%20-87.6768492%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
